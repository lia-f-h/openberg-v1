# %%
import numpy as np

dict_in = {'seed':{'lat':80.0,'length':np.array([1,2,3])},'config':{'drift:current_drag':True}}
#dict_in = {'config':{'drift:current_drag':True}}
iceberg = dict_in.get('seed', {})
print(iceberg)
# Out:
# {'lat': 80.0, 'length': array([1, 2, 3])}

# %%
path_env = './bla/bla/'
'%si'%path_env
# Out:
# './bla/bla/i'

# %%
for i in iceberg: print(i)
# Out:
# lat
# length

# %%
i
# Out:
# 'length'

# %%
ib2 = {'lat':80.0,'length':np.array([1,2,3])}
iceberg==ib2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 ib2 = {'lat':80.0,'length':np.array([1,2,3])}
# ----> 2 iceberg==ib2
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
ib2['lat','length']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ib2['lat','length']
#
# KeyError: ('lat', 'length')
